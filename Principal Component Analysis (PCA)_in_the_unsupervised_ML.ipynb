# %% [markdown]
# <a href="https://colab.research.google.com/github/waghvaishnav/Unsupervised-Machine-Learning-Algorithms-and-Techniques-Lab-/blob/main/Principal%20Component%20Analysis%20(PCA)_in_the_unsupervised_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
iris = load_iris()
x = iris.data
y= iris.target

features = iris.feature_names
print(features)
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %%
x_scaled = StandardScaler().fit_transform(x)

pca = PCA(n_components=2)
x_pca = pca.fit_transform(x_scaled)

df = pd.DataFrame(x_pca,columns=["pca1","pca2"])


df["target"] = y

df.head()
# Out:
#        pca1      pca2  target
# 0 -2.264703  0.480027       0
# 1 -2.080961 -0.674134       0
# 2 -2.364229 -0.341908       0
# 3 -2.299384 -0.597395       0
# 4 -2.389842  0.646835       0

# %%
print("Explained Variance Ratio:", pca.explained_variance_ratio_*100)
# Out:
# Explained Variance Ratio: [72.96244541 22.85076179]

# %%
plt.figure(figsize=(7,5))
colors = ['r', 'g', 'b']
labels = iris.target_names

for i, color, label in zip([0,1,2], colors, labels):
    plt.scatter(df['pca1'],df['pca2'],c="red")

plt.xlabel("PCA 1")
plt.ylabel("PCA 2")
plt.title("PCA of Iris Dataset")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /tmp/ipython-input-2111383684.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
